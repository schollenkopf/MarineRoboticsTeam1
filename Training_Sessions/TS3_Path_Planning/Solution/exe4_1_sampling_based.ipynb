# %% [markdown]
# # 3D Sampling-based Path Planning

# %%
from Sampling_based_Planning.rrt_3D.rrt3D import rrt
from Sampling_based_Planning.rrt_3D import plot_util3D, env3D
import time

# %%
p = rrt()
starttime = time.time()
p.run()
print('time used = ' + str(time.time() - starttime))
# Out:
# c:\Users\yaqpr\AINavigator\course\34763-autonomous-marine-robotics\Training_Sessions\TS3_Path_Planning\Solution\Sampling_based_Planning\rrt_3D/../../Sampling_based_Planning\rrt_3D\utils3D.py:117: RuntimeWarning: invalid value encountered in scalar divide
#   I = [(p1[0] - p0[0]) / dist, (p1[1] - p0[1]) / dist, (p1[2] - p0[2]) / dist]  # unit direction
# Total distance = 51.34117557835379
# time used = 98.41774296760559
